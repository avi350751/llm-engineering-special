# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
import requests

headers = {"Authorization":f"Bearer {api_key}", "Content-Type":"application/json"}

payload = {
    "model":"gpt-5-nano",
    "messages":[{
        "role":"user","content":" Tell me a joke"
    }]
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': ' Tell me a joke'}]}

# %%
response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'chatcmpl-DORl4g40YJtbOBT9mvYs60CLrHJg7',
#  'object': 'chat.completion',
#  'created': 1774718946,
#  'model': 'gpt-5-nano-2025-08-07',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'Why don’t scientists trust atoms? Because they make up everything.',
#     'refusal': None,
#     'annotations': []},
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 10,
#   'completion_tokens': 278,
#   'total_tokens': 288,
#   'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#   'completion_tokens_details': {'reasoning_tokens': 256,
#    'audio_tokens': 0,
#    'accepted_prediction_tokens': 0,
#    'rejected_prediction_tokens': 0}},
#  'service_tier': 'default',
#  'system_fingerprint': None}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'Why don’t scientists trust atoms? Because they make up everything.'

# %% [markdown]
# ### OpenAI Package

# %%
from openai import OpenAI
openai = OpenAI()

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[{
        "role":"user","content":"Tell me an interesting fact abou the Sun"
    }]
)

response.choices[0].message.content
# Out:
# "An interesting fact: The Sun contains about 99.86% of the Solar System's mass, so nearly everything else (planets, asteroids, comets) adds up to only about 0.14% of the total. Want another cool Sun fact?"

# %%
gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/",api_key=os.getenv("GOOGLE_API_KEY"))

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[{
        "role":"user","content":"Tell me an interesting fact abou the Sun"
    }]
)

response.choices[0].message.content
# Out:
# 'One fascinating fact: the Sun fuses about 600 million tons of hydrogen into helium every second in its core, and the energy released corresponds to about 4 million tons of mass being converted to energy each second (via E=mc^2).'
