# %% [markdown]
# ### Tokenizing with code

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1")
tokens = encoding.encode("My name is Avi")

# %%
tokens
# Out:
# [5444, 1308, 382, 100999]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} - {token_text}")
# Out:
# 5444 - My
# 1308 -  name
# 382 -  is
# 100999 -  Avi

# %%
encoding.decode([336])
# Out:
# ' S'

# %% [markdown]
# ### Illusion of memory

# %%
from openai import OpenAI
openai = OpenAI()

# %%
messages = [
    {"role":"system","content":"You are a helpful assistant"},
    {"role":"user","content":"Hello! I am Avi"}
]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=messages
)

response.choices[0].message.content
# Out:
# 'Hello, Avi! How can I help you today? 😊'

# %%
messages = [
    {"role":"system","content":"You are a helpful assistant"},
    {"role":"user","content":"What's my name?"}
]

response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=messages
)

response.choices[0].message.content
# Out:
# 'I don’t actually know your name yet! You haven’t told me. If you\'d like, you can share your name, or I can just call you "friend." What do you prefer?'

# %%
messages = [
    {"role":"system","content":"You are a helpful assistant"},
    {"role":"user","content":"Hello! I am Avi"},
    {"role":"assistant","content":"Hi! Avi, How can I assist you today?"},
    {"role":"user","content":"What's my name?"}
]

response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=messages
)

response.choices[0].message.content
# Out:
# 'Your name is Avi! How can I help you today? 😊'
